# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def contar(img):
    img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
    _, binaria = cv2.threshold(img_gris, 127, 255, cv2.THRESH_BINARY)  
    borde, _ = cv2.findContours(binaria, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cont = len(borde)
    return cont

image = cv2.imread('nami.jpg')
img_cont = contar(image)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) 
plt.title(f'Contados: {img_cont}')  
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def contar(img):
    img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binaria = cv2.threshold(img_gris, 127, 255, cv2.THRESH_BINARY)
    bordes, _ = cv2.findContours(binaria, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cont = len(bordes)
    return bordes, cont

image = cv2.imread('nami.jpg')
bordes, img_cont = contar(image)

image_contours = cv2.drawContours(image.copy(), bordes, -1, (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.title(f'Contados: {img_cont}')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import skimage.measure as ms

def contar(image):
    img_gris = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binaria = cv2.threshold(img_gris, 127, 255, cv2.THRESH_BINARY)
    #_, borde, _ = cv2.findContours(binaria, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    etiquetar=ms.label(binaria,connectivity=2)
    cont = np.max(etiquetar)
    return cont

image = cv2.imread('nami.jpg')
img_cont = contar(image)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title(f'Contados: {img_cont}')
plt.show()
