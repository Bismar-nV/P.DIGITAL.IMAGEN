# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy
import time

# %%
def open_img(img):
    ruote=("img1.png"+ img)
    img=Image.open(ruote)
    img.show()
open_img("img1.png")

# %%
import  matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams['figure.figsize'] = [10,5]

# %%
img=cv2.imread('img1.png')
print('size : ', img.shape)
# Out:
# size :  (512, 512, 3)

# %%
plt.imshow(img)
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

image =cv2.imread('img1.png',cv2.IMREAD_GRAYSCALE)
#guandamos profundidad original para mostrar
original_img=image.dtype
print('profundidad original de color : ',original_img)
#transformacion de imagen a 16bits
image_16bits=np.uint16(image)
nueva_img =image_16bits.dtype

print('profundidad nueva de color : ',nueva_img)

#guardamos la imagen tratada
cv2.imwrite('image16bits.jpg', image_16bits)

img_guardada=cv2.imread('image16bits.jpg',cv2.IMREAD_UNCHANGED)

plt.figure(figsize =(10,5))

plt.subplot(121)
plt.title('original')
plt.imshow(image,cmap='gray')

plt.subplot(122)
plt.title('imagen tratada 16bits')
plt.imshow(img_guardada,cmap='gray')

plt.show()
# Out:
# profundidad original de color :  uint8
# profundidad nueva de color :  uint16

# %%
import cv2
import matplotlib.pyplot as plt

def mostraImagen(ruta_imagen):
    imagen_bgr = cv2.imread(ruta_imagen)
    plt.imshow(cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB))
    plt.title('Imagen en formato BGR')
    plt.show()
    imagen_gris = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2GRAY)
    cv2.imwrite('imagen_gris.png', imagen_gris)
    plt.imshow(imagen_gris, cmap='gray')
    plt.title('Imagen en escala de grises')
    plt.show()

ruta_imagen = './IMG/img1.png'
mostraImagen(ruta_imagen)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Lee la imagen en escala de grises
img = cv2.imread('./IMG/img3.jpg', 0)

# Aplica el método de Otsu
_, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Muestra la imagen original y la imagen umbralizada
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray')
plt.title('DANIEL EL MONO'), plt.xticks([]), plt.yticks([])

plt.subplot(1, 2, 2), plt.imshow(thresh, cmap='gray')
plt.title('Umbralizado con Otsu'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

def histograma(imagen):

    histo=cv2.calcHist([imagen],[0],None,[256],[0,256])
    plt.figure(figsize=(10,5))
    plt.plot(histo,color="blue")
    plt.title('HISTOGRAMA')
    plt.xlabel('intensidad_pixel')
    plt.ylabel('frecuencia')
    plt.show()

ima=cv2.imread('./IMG/img3.jpg',0)
histograma(ima)

# %%
import cv2 
import matplotlib.pyplot as plt
img=cv2.imread('./IMG/nami.jpg',0)
#ESTE ES UMBRALIZACION BINARIA
_,umbralbi=cv2.threshold(img,127,255, cv2.THRESH_BINARY)
_,umbralbi_inc_bi=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)

plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title('imagen inicial')

plt.subplot(1,3,2)
plt.imshow(umbralbi, cmap='gray')
plt.title('bianria')

plt.subplot(1,3,3)
plt.imshow(umbralbi_inc_bi, cmap='gray')
plt.title('BInaRIO INVERSA')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('./IMG/nami.jpg', 0)
#umb_adap=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY)
#umb_adap_gauss=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY)
umb_adap = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
umb_adap_gauss = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)




plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title('imagen inicial')

plt.subplot(1,3,2)
plt.imshow(umb_adap, cmap='gray')
plt.title('Umbralizacion adaptable')

plt.subplot(1,3,3)
plt.imshow(umb_adap_gauss, cmap='gray')
plt.title('umbrali adaptable gaus')

plt.show()
